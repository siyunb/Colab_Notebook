# %%
import tensorflow as tf
tf.test.gpu_device_name()
# Out:
# '/device:GPU:0'

# %%
import requests

# %%
# !pip3 install https://download.pytorch.org/whl/cu80/torch-1.0.0-cp36-cp36m-linux_x86_64.whl
# !pip3 install torchvision

# %%
import torch
x = torch.empty(5, 3)
print(x)

# %%
# !/opt/bin/nvidia-smi
# Out:
# Wed Dec 30 15:00:45 2020
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 418.67       Driver Version: 418.67       CUDA Version: 10.1     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   46C    P0    28W /  70W |    227MiB / 15079MiB |      0%      Default |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                       GPU Memory |
# ...

# %%
# !df -lh
# Out:
# Filesystem      Size  Used Avail Use% Mounted on
# overlay          69G   33G   37G  48% /
# tmpfs            64M     0   64M   0% /dev
# tmpfs           6.4G     0  6.4G   0% /sys/fs/cgroup
# shm             5.8G     0  5.8G   0% /dev/shm
# /dev/sda1        75G   34G   42G  45% /opt/bin
# tmpfs           6.4G   16K  6.4G   1% /var/colab
# tmpfs           6.4G     0  6.4G   0% /proc/acpi
# tmpfs           6.4G     0  6.4G   0% /proc/scsi
# tmpfs           6.4G     0  6.4G   0% /sys/firmware

# %%
# !cat /proc/cpuinfo | grep model\ name
# Out:
# model name	: Intel(R) Xeon(R) CPU @ 2.20GHz
# model name	: Intel(R) Xeon(R) CPU @ 2.20GHz

# %%
# !cat /proc/meminfo | grep MemTotal
# Out:
# MemTotal:       13333596 kB

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-ec6bc886-3988-4611-a65f-3f2dd9fdaac2" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-ec6bc886-3988-4611-a65f-3f2dd9fdaac2">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving Annals of Applied Statistics.csv to Annals of Applied Statistics (1).csv
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-31-89f6f9c8482d> in <module>()
#       1 from google.colab import files
# ----> 2 uploaded = pd.read_csv(files.upload())
#
# ...

# %%
for fn in uploaded.keys():
  print('User uploaded file "{name}" with length {length} bytes'.format(
      name=fn, length=len(uploaded[fn])))
# Out:
# User uploaded file "Annals of Applied Statistics.csv" with length 7394952 bytes

# %%
bytes.decode(uploaded['Annals of Applied Statistics.csv'])
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
with open("my_data.csv", 'w') as f:
  f.write(bytes.decode(uploaded['Annals of Applied Statistics.csv']))

# %%
# !pwd
# Out:
# /content/test

# %%
# !ls
# Out:
# 'Annals of Applied Statistics.csv'

# %%
with open('example.txt', 'w') as f:
  f.write('some content')

files.download('example.txt')

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
with open('/content/drive/My Drive/foo.txt', 'w') as f:
  f.write('Hello Google Drive!')

# %%
from pydrive.auth import GoogleAuth
from pydrive.drive import GoogleDrive
from google.colab import auth
from oauth2client.client import GoogleCredentials

# %%
auth.authenticate_user()
gauth = GoogleAuth()
gauth.credentials = GoogleCredentials.get_application_default()
drive = GoogleDrive(gauth)

# %%
uploaded = drive.CreateFile({'title': 'Sample upload1.txt'})
uploaded.SetContentString('Sample upload file content')

# %%
uploaded
# Out:
# GoogleDriveFile({'title': 'Sample upload.txt', 'mimeType': 'text/plain'})

# %%
uploaded.Upload()
print('Uploaded file with ID {}'.format(uploaded.get('id')))
# Out:
# Uploaded file with ID 1WmA0x0NNeAaXdldqSHVGsobs3ZD0LoE_

# %%
downloaded = drive.CreateFile({'id': uploaded.get('id')})
print('Downloaded content "{}"'.format(downloaded.GetContentString()))
# Out:
# Downloaded content "Sample upload file content"

# %%
downloaded = drive.CreateFile({'id':'1bd48kPFXGrngJiDr2oz9MJF-WZM1bCzk'}) # replace the id with id of file you want to access
downloaded.GetContentFile('xyz.txt')
